# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
import xgboost as xgb
from sklearn.linear_model import BayesianRidge
from sklearn.model_selection import KFold, RepeatedKFold
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from scipy import sparse
import warnings
import time
import sys
import os
import re
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
from sklearn.metrics import mean_squared_error
from sklearn.metrics import log_loss
from dateutil.parser import parse
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns',None)
pd.set_option('max_colwidth',100)

train = pd.read_csv('datalab/7955/jinnan_round1_train_20181227.csv', encoding = 'gb18030')
test  = pd.read_csv('datalab/7955/jinnan_round1_testA_20181227.csv', encoding = 'gb18030')
# 删除异常值
train = train[train['收率'] > 0.87]
# 计算时间差
def TimeDiff(szTime1, szTime2):
    d = 0
    if "24:00:00" == szTime1:
        szTime1 = "23:59:59"
        d = -1
    if "24:00:00" == szTime2:
        szTime2 = "23:59:59"
        d = d + 1
    a = parse(szTime1)
    b = parse(szTime2)
    timeDiff = b-a
    if timeDiff.days == -1:
        return TimeDiff(szTime1, "23:59:59") + TimeDiff("00:00:00", szTime2) + 1 + d
    return timeDiff.seconds + d
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
train.shape,test.shape
# Out:
# ((1381, 44), (150, 43))

# %%
# 合并数据集
target = train['收率']
del train['收率']
data = pd.concat([train,test],axis=0,ignore_index=True)
data["id"] = data["样本id"]
data.shape
# Out:
# (1531, 44)

# %%
#分离时间段
IntervalT_index = ["A20","A28","B4","B9","B10","B11"]
for col in IntervalT_index:
    col_per = col+"_per"
    col_last = col+"_last"
    data[col_per] = data.A1
    data[col_last] = data.A1
    for i in data.index:
        intervalTmp = data.loc[[i], [col]]
        #print(intervalTmp)
        if pd.isnull(intervalTmp.values[0][0]):
            data.loc[[i], [col_per]] = data.loc[[1],["A2"]]
            data.loc[[i], [col_last]] = data.loc[[1],["A2"]]
        else:
            splitList = intervalTmp.values[0][0].split("-")
            col_per_value = splitList[0]
            col_last_value = splitList[1]
            data.loc[[i], [col_per]] = col_per_value+ ":00"
            data.loc[[i], [col_last]] = col_last_value+ ":00"
print("结束")
# Out:
# 结束

# %% [markdown]
# # 计算时间间隔

# %%
T_col = ["A5","A7","A9","A11","A14","A16",
         "A20_per","A20_last","A24","A26","A28_per",
         "A28_last","B4_per","B4_last","B5","B7",
         "B9_per","B9_last","B10_per","B10_last","B11_per","B11_last"]

# %%
data["oTmp"] = data.A5
try:
    for i1 in range(len(T_col)):
        col = T_col[i1]
        print(col)
        col_o = col + "_o"
        data[col_o] = data.A1
        for i in data.index:
            #print(i)
            T_Tmp = data.loc[[i], [col]].values[0][0]
            O_Tmp = data.loc[[i], ["oTmp"]].values[0][0]
            if pd.isnull(T_Tmp):
                data.loc[[i], [col_o]] = 0
            else:
                data.loc[[i], [col_o]] = TimeDiff(T_Tmp, O_Tmp)
                data.loc[[i], ["oTmp"]] = T_Tmp
except:
    print(i1,i,T_Tmp,O_Tmp,data.loc[i]["样本id"])
print("结束")
# Out:
# A5
# A7
# A9
# A11
# A14
# A16
# A20_per
# A20_last
# A24
# A26
# A28_per
# A28_last
# B4_per
# B4_last
# B5
# B7
# B9_per
# B9_last
# B10_per
# B10_last
# B11_per
# B11_last
# 结束

# %%
T_col_drop = ["A7","A9","A11","A14","A16",
         "A20","A20_per","A20_last","A24","A26","A28","A28_per",
         "A28_last","B4","B4_per","B4_last","B5","B7",
         "B9","B9_per","B9_last","B10","B10_per","B10_last","B11","B11_per","B11_last",
         "oTmp","样本id"]
data.drop(T_col_drop, axis=1, inplace=True)

# %%
train = data[:train.shape[0]]
train["target"] = target
test  = data[train.shape[0]:]
train.to_csv("o/trainDropALLT.csv", index=False)
test.to_csv("o/testDropALLT.csv", index=False)

# %%
data.drop(["A5"], axis=1, inplace=True)

# %%
x = 0.123456
round(x, 3)
# Out:
# 0.123

# %%
AA = ["1","2","3"]
for i in range(len(T_col)):
    print(i)
    print(type(i))
# Out:
# 0
# <class 'int'>
# 1
# <class 'int'>
# 2
# <class 'int'>
# 3
# <class 'int'>
# 4
# <class 'int'>
# 5
# <class 'int'>
# 6
# <class 'int'>
# 7
# <class 'int'>
# 8
# <class 'int'>
# 9
# <class 'int'>
# 10
# <class 'int'>
# 11
# <class 'int'>
# 12
# <class 'int'>
# 13
# <class 'int'>
# 14
# <class 'int'>
# 15
# <class 'int'>
# 16
# <class 'int'>
# 17
# <class 'int'>
# 18
# <class 'int'>
# 19
# <class 'int'>
# 20
# <class 'int'>

# %%
AA[1]
# Out:
# '2'

# %%
data.head()
# Out:
#           样本id   A1  A2     A3   A4        A5    A6   A7  A8        A9  A10  \
# 0     sample_1  300 NaN  405.0  700   6:30:00  25.0  NaN NaN   8:00:00  100
# 1   sample_100  300 NaN  405.0  700  20:00:00  29.0  NaN NaN  22:00:00  101
# 2  sample_1000  300 NaN  405.0  700  17:00:00  30.0  NaN NaN  18:00:00  100
# 3  sample_1002  300 NaN  405.0  700  14:00:00  21.0  NaN NaN  15:00:00  100
# 4  sample_1004  300 NaN  405.0  700   7:00:00  20.0  NaN NaN   8:30:00  100
#
#         A11    A12  A13       A14    A15       A16    A17  A18  A19  \
# 0   9:00:00  103.0  0.2  10:00:00  104.0  11:00:00  105.0  0.2  300
# 1  23:00:00  103.0  0.2   0:00:00  104.0   1:00:00  105.0  0.2  200
# 2  19:00:00  101.0  0.2  20:00:00  103.0  21:00:00  105.0  0.2  200
# 3  16:00:00  101.0  0.2  17:00:00  102.0  18:00:00  103.0  0.2  200
# 4   9:30:00  102.0  0.2  10:30:00  103.0  11:30:00  105.0  0.2  200
#
#            A20   A21   A22  A23       A24   A25       A26   A27          A28  \
# ...

# %%
stats = []
for col in train.columns:
    stats.append([col, train[col].nunique(), train[col].isnull().sum() * 100 / train.shape[0],
                  train[col].value_counts(normalize=True, dropna=False).values[0] * 100, train[col].dtype])

stats_columns = ['Feature', 'Unique_values', 'Percent_missing', 'Percentage_biggest', 'type']
stats_df = pd.DataFrame(stats, columns = stats_columns)
stats_df.sort_values('Percent_missing', ascending=False)[:10]
print(stats_df)
# Out:
#        Feature  Unique_values  Percent_missing  Percentage_biggest     type
# 0         样本id           1381         0.000000            0.072411   object
# 1           A1              3         0.000000           98.696597    int64
# 2           A2              1        97.175959           97.175959  float64
# 3           A3              3         2.824041           95.944967  float64
# 4           A4              4         0.000000           95.944967    int64
# 5           A5             64         0.000000           19.478639   object
# 6           A6             38         0.000000           35.698769  float64
# 7           A7             75        89.210717           89.210717   object
# 8           A8              8        89.210717           89.210717  float64
# 9           A9             93         0.000000           18.247647   object
# 10         A10              4         0.000000           46.850109    int64
# ...

# %%
ddd = data.loc[[1],["A20_per"]]
ddd
# Out:
#   A20_per
# 1    1:00

# %%
ddd = null
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-92663f80b9ce> in <module>()
# ----> 1 ddd = null
#
# NameError: name 'null' is not defined

# %%
pd.isnull(ddd.values[0][0])
# Out:
# True

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1531, step=1)

# %%
TimeDiff("00:00:00",ddd.values[0][0] + ":00" )
# Out:
# 3600

# %%
data.lo[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-c402bf503b75> in <module>()
# ----> 1 data[1]
#
# ...

# %%
train.head()
# Out:
#           样本id   A1  A2     A3   A4        A5    A6   A7  A8        A9  A10  \
# 0     sample_1  300 NaN  405.0  700   6:30:00  25.0  NaN NaN   8:00:00  100
# 1   sample_100  300 NaN  405.0  700  20:00:00  29.0  NaN NaN  22:00:00  101
# 2  sample_1000  300 NaN  405.0  700  17:00:00  30.0  NaN NaN  18:00:00  100
# 4  sample_1002  300 NaN  405.0  700  14:00:00  21.0  NaN NaN  15:00:00  100
# 5  sample_1004  300 NaN  405.0  700   7:00:00  20.0  NaN NaN   8:30:00  100
#
#         A11  A12  A13       A14    A15       A16    A17  A18  A19  \
# 0   9:00:00  103  0.2  10:00:00  104.0  11:00:00  105.0  0.2  300
# 1  23:00:00  103  0.2   0:00:00  104.0   1:00:00  105.0  0.2  200
# 2  19:00:00  101  0.2  20:00:00  103.0  21:00:00  105.0  0.2  200
# 4  16:00:00  101  0.2  17:00:00  102.0  18:00:00  103.0  0.2  200
# 5   9:30:00  102  0.2  10:30:00  103.0  11:30:00  105.0  0.2  200
#
#            A20   A21   A22  A23       A24  A25       A26  A27          A28  \
# ...

# %%
trainA1_300 = train[train.A1 == 300]

# %%
trainA1_300
# Out:
#              样本id   A1  A2     A3   A4        A5    A6   A7  A8        A9  \
# 0        sample_1  300 NaN  405.0  700   6:30:00  25.0  NaN NaN   8:00:00
# 1      sample_100  300 NaN  405.0  700  20:00:00  29.0  NaN NaN  22:00:00
# 2     sample_1000  300 NaN  405.0  700  17:00:00  30.0  NaN NaN  18:00:00
# 3     sample_1001  300 NaN  405.0  700   1:00:00  21.0  NaN NaN   2:30:00
# 4     sample_1002  300 NaN  405.0  700  14:00:00  21.0  NaN NaN  15:00:00
# 5     sample_1004  300 NaN  405.0  700   7:00:00  20.0  NaN NaN   8:30:00
# 6     sample_1005  300 NaN  405.0  700  17:30:00  21.0  NaN NaN  18:30:00
# 7     sample_1006  300 NaN  405.0  700   1:30:00  35.0  NaN NaN   2:30:00
# 8     sample_1007  300 NaN  405.0  700  12:00:00  35.0  NaN NaN  13:00:00
# 9     sample_1008  300 NaN  405.0  700  22:00:00  21.0  NaN NaN  23:30:00
# 10    sample_1009  300 NaN  405.0  700   7:00:00  20.0  NaN NaN   8:00:00
# 11     sample_101  300 NaN  405.0  700   4:00:00  29.0  NaN NaN   6:00:00
# ...

# %%
trainA1_300["收率"].mean()
# Out:
# 0.9233044299201161

# %%
trainA1_250 = train[train.A1 == 250]
trainA1_250["收率"].mean()
# Out:
# 0.926

# %%
feature = 200
trainA1 = train[train.A1 == feature]
trainA1["收率"].mean()
# Out:
# 0.9155384615384616

# %%
train.describe()
# Out:
#                 A1     A2           A3           A4           A6          A8  \
# count  1396.000000   42.0  1354.000000  1396.000000  1396.000000  149.000000
# mean    298.853868  125.0   403.515510   705.974212    28.287751   78.818792
# std      10.130552    0.0    13.348093    53.214754     6.742765    2.683920
# min     200.000000  125.0   270.000000   470.000000    17.000000   70.000000
# 25%     300.000000  125.0   405.000000   700.000000    24.000000   80.000000
# 50%     300.000000  125.0   405.000000   700.000000    29.000000   80.000000
# 75%     300.000000  125.0   405.000000   700.000000    30.000000   80.000000
# max     300.000000  125.0   405.000000   980.000000    97.000000   82.000000
#
#                A10          A12          A13          A15          A17  \
# count  1396.000000  1396.000000  1396.000000  1396.000000  1396.000000
# mean    100.861032   102.641834     0.199907   103.829370   104.766905
# ...

# %%
value_counts = train.A1.value_counts()
value_counts
# Out:
# 300    1377
# 200      13
# 250       6
# Name: A1, dtype: int64

# %%
type(value_counts)
# Out:
# pandas.core.series.Series

# %%
value_counts.index[1]
# Out:
# 200

# %%
for i in value_counts.index:
    print(i)
# Out:
# 300
# 200
# 250

# %%
feature_name = [i for i in train.columns if i not in ['id','收率',"target"]]
feature_name
# Out:
# ['A1',
#  'A2',
#  'A3',
#  'A4',
#  'A5',
#  'A6',
#  'A8',
#  'A10',
#  'A12',
#  'A13',
#  'A15',
#  'A17',
#  'A18',
#  'A19',
#  'A21',
#  'A22',
#  'A23',
#  'A25',
#  'A27',
#  'B1',
#  'B2',
#  'B3',
#  'B6',
#  'B8',
#  'B12',
#  'B13',
#  'B14',
#  'id',
#  'A5_o',
#  'A7_o',
#  'A9_o',
#  'A11_o',
#  'A14_o',
#  'A16_o',
#  'A20_per_o',
#  'A20_last_o',
#  'A24_o',
#  'A26_o',
#  'A28_per_o',
#  'A28_last_o',
#  'B4_per_o',
#  'B4_last_o',
#  'B5_o',
#  'B7_o',
#  'B9_per_o',
#  'B9_last_o',
#  'B10_per_o',
#  'B10_last_o',
#  'B11_per_o',
#  'B11_last_o']

# %%
for col in feature_name:
    #col = "A1"
    print(col)
    vList = train[col].value_counts().index
    vMean = []
    for v in vList:
        dfTmp = train[train[col] == v]
        mean = dfTmp["target"].mean()
        vMean.append(mean)
    plt.figure(figsize=(8,6))
    plt.scatter(vList, vMean)
    plt.xlabel(col, fontsize=12)
    plt.ylabel('rate', fontsize=12)
    plt.show()
# Out:
# A1
# A2
# A3
# A4
# A5
# A6
# A8
# A10
# A12
# A13
# A15
# A17
# A18
# A19
# A21
# A22
# A23
# A25
# A27
# B1
# B2
# B3
# B6
# B8
# B12
# B13
# B14
# id

# %%
vMean
# Out:
# [0.9233044299201161, 0.9155384615384616, 0.926]

# %%
vList
# Out:
# Int64Index([300, 200, 250], dtype='int64')

# %%
plt.figure(figsize=(8,6))
plt.scatter(vList, vMean)
plt.xlabel('index', fontsize=12)
plt.ylabel('yield', fontsize=12)
plt.show()
